# %%
import yaml
from IPython.display import display, Javascript
from VideoAnalysis.Helms import VideoConfigWidget

# %%
js_init = Javascript(data='require(["widgets/js/roi_init"], function(){})')
display(js_init)

# %%
videoDir = './sample'
storeDir = './sample'

vcw1 = VideoConfigWidget(
    videoDir=videoDir, 
    resultsDir=storeDir,
    configDir=storeDir
)
def reportCancel(self):
    print "Cancelled"
vcw1.on_cancel(reportCancel)
display(vcw1)

# %%
vcw1.value
# Out:
# {'configFile': './sample/short_test_new.yml',
#  'cropRegions': [<wormtracker.WormVideoRegion at 0x7fef0e078990>,
#   <wormtracker.WormVideoRegion at 0x7fef0b9844d0>,
#   <wormtracker.WormVideoRegion at 0x7fef0b984650>,
#   <wormtracker.WormVideoRegion at 0x7fef0b984f50>],
#  'frameRate': 11.5,
#  'nFrames': 1201,
#  'numberFrames': 'undefined',
#  'pixelSize': 21.707235785209786,
#  'pixelsPerMicron': 0.04606758824084592,
#  'referenceDistance': 25000,
#  'resultsStorePath': '/worms',
#  'storeFile': './sample/short_test.h5',
#  'videoFile': './sample/short_test.avi',
#  'videoInfoStorePath': '/video',
#  'wormImageProcessor': <wormtracker.wormimageprocessor.WormImageProcessor instance at 0x7fef0e13b5f0>}

# %%
print yaml.dump(vcw1.value)
# Out:
# configFile: ./sample/short_test_new.yml
# cropRegions:
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [403.898451089859, 129.2296929359436, 384.75, 427.5]
#   foodCircle: [580.242201089859, 310.9171929359436, 100.15077134976607]
#   frameRate: 11.5
#   frameSize: &id001 !!python/tuple [2736, 2192]
#   imageProcessor: &id002 !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
#     backgroundDiskRadius: 5
#     compactnessThreshold: 10
#     expectedWormLength: 1000
#     expectedWormWidth: 50
#     frameRate: 11.5
#     holeAreaThreshold: 10
#     numberOfPosturePoints: -1
#     pixelSize: 0.04606758824084592
#     threshold: 0.9
#     wormAreaThresholdRange: &id003 [0.5, 1.5]
#     wormDiskRadius: 2
#   outputPrefix: !!python/unicode 'N2_1_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '1'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [898.195326089859, 131.9015679359436, 390.09375, 435.515625]
#   foodCircle: [1102.593763589859, 356.3390679359436, 101.08201396570648]
#   frameRate: 11.5
#   frameSize: *id001
#   imageProcessor: *id002
#   outputPrefix: !!python/unicode 'N2_2_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '2'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [1512.726576089859, 155.9484429359436, 392.765625, 430.171875]
#   foodCircle: [1689.070326089859, 341.6437554359436, 95.4517761225081]
#   frameRate: 11.5
#   frameSize: *id001
#   imageProcessor: *id002
#   outputPrefix: !!python/unicode 'N2_3_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '3'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [2007.023451089859, 158.6203179359436, 382.078125, 424.828125]
#   foodCircle: [2191.382826089859, 363.0187554359436, 97.30358351942984]
#   frameRate: 11.5
#   frameSize: *id001
#   imageProcessor: *id002
#   outputPrefix: !!python/unicode 'N2_4_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '4'
# frameRate: 11.5
# nFrames: 1201
# numberFrames: undefined
# pixelSize: 21.707235785209786
# pixelsPerMicron: 0.04606758824084592
# referenceDistance: 25000
# resultsStorePath: /worms
# storeFile: ./sample/short_test.h5
# videoFile: ./sample/short_test.avi
# videoInfoStorePath: /video
# wormImageProcessor: !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
#   backgroundDiskRadius: 5
#   compactnessThreshold: 10
#   expectedWormLength: 1000
#   expectedWormWidth: 50
#   frameRate: 11.5
#   holeAreaThreshold: 10
#   numberOfPosturePoints: -1
#   pixelSize: 0.04606758824084592
#   threshold: 0.9
#   wormAreaThresholdRange: *id003
#   wormDiskRadius: 2

# %%
paramYAML = """
configFile: !!python/unicode './sample/short_test_new.yml'
cropRegions:
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [402.562513589859, 129.6750190258026, 384.75, 424.828125]
  foodCircle: [573.562513589859, 314.0343940258026, 100.15077134976607]
  frameRate: 11.5
  frameSize: &id001 !!python/tuple [2736, 2192]
  imageProcessor: &id002 !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
    backgroundDiskRadius: 5
    compactnessThreshold: 10
    expectedWormLength: 1000
    expectedWormWidth: 70
    frameRate: 11.5
    holeAreaThreshold: 10
    numberOfPosturePoints: 30
    pixelSize: 0.04531953691910917
    resultsStorePath: !!python/unicode '/worms'
    threshold: 0.9
    videoInfoStorePath: !!python/unicode '/video'
    wormAreaThresholdRange: [0.5, 1.5]
    wormDiskRadius: 2
  outputPrefix: !!python/unicode 'N2_1_'
  pixelSize: 0.04531953691910917
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '1'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [899.531263589859, 140.3625190258026, 392.765625, 419.484375]
  foodCircle: [1095.914076089859, 358.1203315258026, 102.0397423006794]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_2_'
  pixelSize: 0.04531953691910917
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '2'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [1514.062513589859, 156.3937690258026, 382.078125, 422.15625]
  foodCircle: [1690.406263589859, 338.0812690258026, 96.37286825828173]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_3_'
  pixelSize: 0.04531953691910917
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '3'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [2011.031263589859, 159.0656440258026, 376.734375, 424.828125]
  foodCircle: [2187.375013589859, 354.1125190258026, 98.24364841110595]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_4_'
  pixelSize: 0.04531953691910917
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '4'
frameRate: 12.0
nFrames: 1201
numberFrames: undefined
pixelSize: 22.065538793675223
pixelsPerMicron: 0.04531953691910917
referenceDistance: 25000
resultsStorePath: /worms
storeFile: !!python/unicode './sample/short_test.h5'
videoFile: !!python/unicode './sample/short_test.avi'
videoInfoStorePath: /video
wormImageProcessor: !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
  backgroundDiskRadius: 5
  compactnessThreshold: 10
  expectedWormLength: 1000
  expectedWormWidth: 50
  frameRate: 11.5
  holeAreaThreshold: 10
  numberOfPosturePoints: -1
  pixelSize: 0.04531953691910917
  threshold: 0.9
  wormAreaThresholdRange: [0.5, 1.5]
  wormDiskRadius: 2

"""

# %%
params = yaml.load(paramYAML)
params
# Out:
# {'configFile': u'./sample/short_test_new.yml',
#  'cropRegions': [<wormtracker.WormVideoRegion at 0x7fef0b84b350>,
#   <wormtracker.WormVideoRegion at 0x7fef0b84b390>,
#   <wormtracker.WormVideoRegion at 0x7fef0b84b1d0>,
#   <wormtracker.WormVideoRegion at 0x7fef0b84b3d0>],
#  'frameRate': 12.0,
#  'nFrames': 1201,
#  'numberFrames': 'undefined',
#  'pixelSize': 22.065538793675223,
#  'pixelsPerMicron': 0.04531953691910917,
#  'referenceDistance': 25000,
#  'resultsStorePath': '/worms',
#  'storeFile': u'./sample/short_test.h5',
#  'videoFile': u'./sample/short_test.avi',
#  'videoInfoStorePath': '/video',
#  'wormImageProcessor': <wormtracker.wormimageprocessor.WormImageProcessor instance at 0x7fef0b8908c0>}

# %%
vars(params['cropRegions'][0].imageProcessor)
# Out:
# {'backgroundDiskRadius': 5,
#  'compactnessThreshold': 10,
#  'expectedWormLength': 1000,
#  'expectedWormWidth': 70,
#  'frameRate': 11.5,
#  'holeAreaThreshold': 10,
#  'numberOfPosturePoints': 30,
#  'pixelSize': 0.04531953691910917,
#  'resultsStorePath': u'/worms',
#  'threshold': 0.9,
#  'videoInfoStorePath': u'/video',
#  'wormAreaThresholdRange': [0.5, 1.5],
#  'wormDiskRadius': 2}

# %%
print yaml.dump(vcw1.video)
# Out:
# !!python/object:wormtracker.WormVideo
# allSameStrain: true
# firstFrame: null
# frameSize: null
# imageProcessor: &id001 !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
#   backgroundDiskRadius: 5
#   compactnessThreshold: 10
#   expectedWormLength: 1000
#   expectedWormWidth: 50
#   frameRate: 11.5
#   holeAreaThreshold: 10
#   numberOfPosturePoints: -1
#   pixelSize: 0.04606758824084592
#   threshold: 0.9
#   wormAreaThresholdRange: [0.5, 1.5]
#   wormDiskRadius: 2
# logFile: ./sample/short_test.avi_.log
# nFrames: null
# numberOfRegions: 4
# pixelsPerMicron: 0.04606758824084592
# referenceDistance: 25000.0
# regions:
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [403.898451089859, 129.2296929359436, 384.75, 427.5]
#   foodCircle: [580.242201089859, 310.9171929359436, 100.15077134976607]
#   frameRate: 11.5
#   frameSize: &id002 !!python/tuple [2736, 2192]
#   imageProcessor: *id001
#   outputPrefix: !!python/unicode 'N2_1_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '1'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [898.195326089859, 131.9015679359436, 390.09375, 435.515625]
#   foodCircle: [1102.593763589859, 356.3390679359436, 101.08201396570648]
#   frameRate: 11.5
#   frameSize: *id002
#   imageProcessor: *id001
#   outputPrefix: !!python/unicode 'N2_2_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '2'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [1512.726576089859, 155.9484429359436, 392.765625, 430.171875]
#   foodCircle: [1689.070326089859, 341.6437554359436, 95.4517761225081]
#   frameRate: 11.5
#   frameSize: *id002
#   imageProcessor: *id001
#   outputPrefix: !!python/unicode 'N2_3_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '3'
# - !!python/object:wormtracker.WormVideoRegion
#   cropRegion: [2007.023451089859, 158.6203179359436, 382.078125, 424.828125]
#   foodCircle: [2191.382826089859, 363.0187554359436, 97.30358351942984]
#   frameRate: 11.5
#   frameSize: *id002
#   imageProcessor: *id001
#   outputPrefix: !!python/unicode 'N2_4_'
#   pixelSize: 0.04606758824084592
#   resultsStoreFile: ./sample/short_test.h5
#   resultsStorePath: /worms
#   strainName: !!python/unicode 'N2'
#   videoFile: ./sample/short_test.avi
#   wormName: '4'
# resultsStorePath: /worms
# storeFile: ./sample/short_test.h5
# videoFile: ./sample/short_test.avi
# videoInfoStorePath: /video

# %%
videoYAML = """
# !!python/object:wormtracker.WormVideo
allSameStrain: true
firstFrame: null
frameSize: null
imageProcessor: !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
  backgroundDiskRadius: 5
  compactnessThreshold: 10
  expectedWormLength: 1000
  expectedWormWidth: 50
  frameRate: 11.5
  holeAreaThreshold: 10
  numberOfPosturePoints: -1
  pixelSize: 0.046286870312014505
  threshold: 0.9
  wormAreaThresholdRange: [0.5, 1.5]
  wormDiskRadius: 2
logFile: ./sample/short_test.avi_.log
nFrames: null
numberOfRegions: 4
pixelsPerMicron: 0.046286870312014505
referenceDistance: 25000.0
regions:
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [407.906263589859, 131.9015679359436, 384.75, 435.515625]
  foodCircle: [577.570326089859, 314.9250054359436, 102.0397423006794]
  frameRate: 11.5
  frameSize: &id001 !!python/tuple [2736, 2192]
  imageProcessor: &id002 !!python/object:wormtracker.wormimageprocessor.WormImageProcessor
    backgroundDiskRadius: 5
    compactnessThreshold: 10
    expectedWormLength: 1000
    expectedWormWidth: 70
    frameRate: 11.5
    holeAreaThreshold: 10
    numberOfPosturePoints: 30
    pixelSize: 0.046286870312014505
    resultsStorePath: !!python/unicode '/worms'
    threshold: 0.9
    videoInfoStorePath: !!python/unicode '/video'
    wormAreaThresholdRange: [0.5, 1.5]
    wormDiskRadius: 2
  outputPrefix: !!python/unicode 'N2_1_'
  pixelSize: 0.046286870312014505
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '1'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [888.843763589859, 129.2296929359436, 400.78125, 435.515625]
  foodCircle: [1097.250013589859, 356.3390679359436, 102.02225027307156]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_2_'
  pixelSize: 0.046286870312014505
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '2'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [1516.734388589859, 150.6046929359436, 390.09375, 432.84375]
  foodCircle: [1687.734388589859, 340.3078179359436, 92.59502219215472]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_3_'
  pixelSize: 0.046286870312014505
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '3'
- !!python/object:wormtracker.WormVideoRegion
  cropRegion: [2008.359388589859, 158.6203179359436, 376.734375, 432.84375]
  foodCircle: [2188.710951089859, 361.6828179359436, 97.30358351942984]
  frameRate: 11.5
  frameSize: *id001
  imageProcessor: *id002
  outputPrefix: !!python/unicode 'N2_4_'
  pixelSize: 0.046286870312014505
  resultsStoreFile: !!python/unicode './sample/short_test.h5'
  resultsStorePath: /worms
  strainName: !!python/unicode 'N2'
  videoFile: !!python/unicode './sample/short_test.avi'
  wormName: '4'
resultsStorePath: /worms
storeFile: ./sample/short_test.h5
videoFile: ./sample/short_test.avi
videoInfoStorePath: /video
"""

# %%
video = yaml.load(videoYAML)
video

# %%
from wormtracker.config import saveWormVideo

with open(params['configFile'], 'w') as f:
    saveWormVideo(video, f)
